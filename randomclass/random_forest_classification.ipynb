# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       age  salary  experience  credit_score  purchased
# 0      56   21920          26           375          1
# 1      69  126121          37           308          0
# 2      46   97219          25           495          1
# 3      32   96872          37           589          1
# 4      60  101132          24           360          1
# ...   ...     ...         ...           ...        ...
# 4995   24   80726          22           784          1
# 4996   66  112906          29           317          0
# 4997   26   36532          20           777          0
# 4998   53  142689           9           787          0
# 4999   36  102357          12           745          0
#
# [5000 rows x 5 columns]

# %%
input_set = df.drop(columns='purchased')
output_set = df['purchased']

# %%
def gini_index(groups, classes):
    n = sum(len(g) for g in groups)
    gini = 0.0
    for g in groups:
        size = len(g)
        if size == 0:
            continue
        score = 0.0
        labels = g[:, -1]
        for c in classes:
            p = (labels == c).sum() / size
            score += p * p
        gini += (1 - score) * (size / n)
    return gini

# %%
def split_data(idx, val, data):
    return data[data[:, idx] < val], data[data[:, idx] >= val]

# %%
def best_split(data, n_features):
    classes = np.unique(data[:, -1])
    features = np.random.choice(data.shape[1]-1, n_features, replace=False)

    best, val, score, groups = None, None, 1e9, None

    # ✅ SAFE ROW SAMPLING
    n_rows = min(50, len(data))

    for f in features:
        for row in data[np.random.choice(len(data), n_rows, replace=False)]:
            left, right = split_data(f, row[f], data)
            gini = gini_index((left, right), classes)

            if gini < score:
                best, val, score, groups = f, row[f], gini, (left, right)

    # ✅ FALLBACK SAFETY
    if best is None:
        return to_leaf(data)

    return {"index": best, "value": val, "groups": groups}

# %%
def to_leaf(group):
    return Counter(group[:, -1]).most_common(1)[0][0]

# %%
def split_node(node, depth, max_depth):
    left, right = node['groups']
    del node['groups']

    if left.size == 0 or right.size == 0:
        node['left'] = node['right'] = to_leaf(np.vstack((left, right)))
        return

    if depth >= max_depth:
        node['left'], node['right'] = to_leaf(left), to_leaf(right)
        return

    node['left'] = best_split(left, int(np.sqrt(left.shape[1] - 1)))
    split_node(node['left'], depth + 1, max_depth)

    node['right'] = best_split(right, int(np.sqrt(right.shape[1] - 1)))
    split_node(node['right'], depth + 1, max_depth)

# %%
def build_tree(data, max_depth):
    root = best_split(data, int(np.sqrt(data.shape[1] - 1)))
    split_node(root, 1, max_depth)
    return root

# %%
def predict_tree(node, row):
    if row[node['index']] < node['value']:
        return predict_tree(node['left'], row) if isinstance(node['left'], dict) else node['left']
    else:
        return predict_tree(node['right'], row) if isinstance(node['right'], dict) else node['right']

# %%
def random_forest_train(X, y, n_trees=10, max_depth=5):
    data = np.column_stack((X, y))
    trees = []

    for _ in range(n_trees):
        sample = data[np.random.randint(0, len(data), len(data))]
        trees.append(build_tree(sample, max_depth))

    return trees

# %%
def random_forest_predict(trees, row):
    preds = [predict_tree(t, row) for t in trees]
    return Counter(preds).most_common(1)[0][0]

# %%
model = random_forest_train(input_set.values, output_set.values)
model
# Out:
# [{'index': np.int64(3),
#   'value': np.int64(327),
#   'left': {'index': np.int64(2),
#    'value': np.int64(10),
#    'left': {'index': np.int64(0),
#     'value': np.int64(62),
#     'left': {'index': np.int64(2),
#      'value': np.int64(1),
#      'left': {'index': np.int64(3),
#       'value': np.int64(322),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(309),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(3),
#      'left': {'index': np.int64(1),
#       'value': np.int64(101418),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(59449),
#       'left': np.int64(0),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(0),
#     'value': np.int64(53),
#     'left': {'index': np.int64(2),
#      'value': np.int64(19),
#      'left': {'index': np.int64(0),
#       'value': np.int64(41),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(37),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(13),
#      'left': {'index': np.int64(1),
#       'value': np.int64(135657),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(319),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(3),
#    'value': np.int64(535),
#    'left': {'index': np.int64(1),
#     'value': np.int64(90423),
#     'left': {'index': np.int64(1),
#      'value': np.int64(47323),
#      'left': {'index': np.int64(0),
#       'value': np.int64(51),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(23),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(329),
#      'left': {'index': np.int64(0),
#       'value': np.int64(30),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(27),
#       'left': np.int64(0),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(128536),
#     'left': {'index': np.int64(3),
#      'value': np.int64(764),
#      'left': {'index': np.int64(1),
#       'value': np.int64(95645),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(1),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(0),
#      'value': np.int64(64),
#      'left': {'index': np.int64(3),
#       'value': np.int64(826),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(611),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(1),
#   'value': np.int64(25021),
#   'left': {'index': np.int64(0),
#    'value': np.int64(38),
#    'left': {'index': np.int64(0),
#     'value': np.int64(23),
#     'left': {'index': np.int64(0),
#      'value': np.int64(20),
#      'left': {'index': np.int64(2),
#       'value': np.int64(19),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(28),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(773),
#      'left': {'index': np.int64(1),
#       'value': np.int64(24627),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(822),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(24922),
#     'left': {'index': np.int64(0),
#      'value': np.int64(59),
#      'left': {'index': np.int64(2),
#       'value': np.int64(23),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(793),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(0),
#      'value': np.int64(68),
#      'left': {'index': np.int64(3),
#       'value': np.int64(683),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(758),
#       'left': np.int64(1),
#       'right': np.int64(1)}}}},
#   'right': {'index': np.int64(1),
#    'value': np.int64(27130),
#    'left': {'index': np.int64(3),
#     'value': np.int64(333),
#     'left': {'index': np.int64(0),
#      'value': np.int64(31),
#      'left': np.int64(0),
#      'right': np.int64(0)},
#     'right': {'index': np.int64(2),
#      'value': np.int64(35),
#      'left': {'index': np.int64(2),
#       'value': np.int64(29),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(30),
#       'left': np.int64(1),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(27837),
#     'left': {'index': np.int64(3),
#      'value': np.int64(396),
#      'left': {'index': np.int64(3),
#       'value': np.int64(384),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(675),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(86900),
#      'left': {'index': np.int64(0),
#       'value': np.int64(22),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(111299),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(2),
#   'value': np.int64(33),
#   'left': {'index': np.int64(3),
#    'value': np.int64(326),
#    'left': {'index': np.int64(3),
#     'value': np.int64(323),
#     'left': {'index': np.int64(2),
#      'value': np.int64(1),
#      'left': {'index': np.int64(1),
#       'value': np.int64(89906),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(308),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(11),
#      'left': {'index': np.int64(3),
#       'value': np.int64(324),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(48901),
#       'left': np.int64(0),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(23164),
#     'left': {'index': np.int64(0),
#      'value': np.int64(57),
#      'left': {'index': np.int64(1),
#       'value': np.int64(21184),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(825),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(17),
#      'left': {'index': np.int64(0),
#       'value': np.int64(23),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(361),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(0),
#    'value': np.int64(22),
#    'left': {'index': np.int64(3),
#     'value': np.int64(717),
#     'left': {'index': np.int64(3),
#      'value': np.int64(696),
#      'left': {'index': np.int64(1),
#       'value': np.int64(118095),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(698),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(777),
#      'left': {'index': np.int64(2),
#       'value': np.int64(37),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(19),
#       'left': np.int64(1),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(21893),
#     'left': {'index': np.int64(0),
#      'value': np.int64(29),
#      'left': np.int64(1),
#      'right': np.int64(1)},
#     'right': {'index': np.int64(1),
#      'value': np.int64(47094),
#      'left': {'index': np.int64(3),
#       'value': np.int64(832),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(61),
#       'left': np.int64(1),
#       'right': np.int64(1)}}}}},
#  {'index': np.int64(0),
#   'value': np.int64(68),
#   'left': {'index': np.int64(0),
#    'value': np.int64(67),
#    'left': {'index': np.int64(3),
#     'value': np.int64(314),
#     'left': {'index': np.int64(1),
#      'value': np.int64(140617),
#      'left': {'index': np.int64(0),
#       'value': np.int64(33),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(302),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(143973),
#      'left': {'index': np.int64(2),
#       'value': np.int64(7),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(36),
#       'left': np.int64(0),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(19),
#     'left': {'index': np.int64(1),
#      'value': np.int64(71012),
#      'left': {'index': np.int64(3),
#       'value': np.int64(532),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(138313),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(23775),
#      'left': {'index': np.int64(3),
#       'value': np.int64(767),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(33269),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(2),
#    'value': np.int64(18),
#    'left': {'index': np.int64(2),
#     'value': np.int64(8),
#     'left': {'index': np.int64(3),
#      'value': np.int64(346),
#      'left': {'index': np.int64(0),
#       'value': np.int64(68),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(5),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(87766),
#      'left': {'index': np.int64(1),
#       'value': np.int64(70492),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(13),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(32),
#     'left': {'index': np.int64(3),
#      'value': np.int64(578),
#      'left': {'index': np.int64(2),
#       'value': np.int64(23),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(29),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(60644),
#      'left': {'index': np.int64(0),
#       'value': np.int64(69),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(69),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(0),
#   'value': np.int64(21),
#   'left': {'index': np.int64(2),
#    'value': np.int64(6),
#    'left': {'index': np.int64(0),
#     'value': np.int64(19),
#     'left': {'index': np.int64(3),
#      'value': np.int64(396),
#      'left': {'index': np.int64(3),
#       'value': np.int64(364),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(755),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(1),
#      'left': {'index': np.int64(1),
#       'value': np.int64(137769),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(36322),
#       'left': np.int64(0),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(138094),
#     'left': {'index': np.int64(3),
#      'value': np.int64(765),
#      'left': {'index': np.int64(3),
#       'value': np.int64(735),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(58507),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(619),
#      'left': {'index': np.int64(2),
#       'value': np.int64(27),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(138747),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(3),
#    'value': np.int64(725),
#    'left': {'index': np.int64(0),
#     'value': np.int64(45),
#     'left': {'index': np.int64(2),
#      'value': np.int64(1),
#      'left': {'index': np.int64(0),
#       'value': np.int64(43),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(149716),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(0),
#      'value': np.int64(47),
#      'left': {'index': np.int64(1),
#       'value': np.int64(97154),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(17),
#       'left': np.int64(1),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(139501),
#     'left': {'index': np.int64(1),
#      'value': np.int64(134012),
#      'left': {'index': np.int64(2),
#       'value': np.int64(25),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(138222),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(801),
#      'left': {'index': np.int64(0),
#       'value': np.int64(37),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(22),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(1),
#   'value': np.int64(141145),
#   'left': {'index': np.int64(3),
#    'value': np.int64(323),
#    'left': {'index': np.int64(2),
#     'value': np.int64(10),
#     'left': {'index': np.int64(1),
#      'value': np.int64(47197),
#      'left': {'index': np.int64(2),
#       'value': np.int64(8),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(51),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(309),
#      'left': {'index': np.int64(1),
#       'value': np.int64(98282),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(315),
#       'left': np.int64(0),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(2),
#     'left': {'index': np.int64(0),
#      'value': np.int64(56),
#      'left': {'index': np.int64(3),
#       'value': np.int64(522),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(134778),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(23262),
#      'left': {'index': np.int64(3),
#       'value': np.int64(357),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(5),
#       'left': np.int64(1),
#       'right': np.int64(1)}}}},
#   'right': {'index': np.int64(0),
#    'value': np.int64(22),
#    'left': {'index': np.int64(2),
#     'value': np.int64(8),
#     'left': {'index': np.int64(2),
#      'value': np.int64(5),
#      'left': {'index': np.int64(0),
#       'value': np.int64(21),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(21),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(25),
#      'left': {'index': np.int64(1),
#       'value': np.int64(141770),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(148128),
#       'left': np.int64(1),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(149688),
#     'left': {'index': np.int64(3),
#      'value': np.int64(801),
#      'left': {'index': np.int64(3),
#       'value': np.int64(787),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(37),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(37),
#      'left': {'index': np.int64(2),
#       'value': np.int64(33),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(33),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(2),
#   'value': np.int64(39),
#   'left': {'index': np.int64(2),
#    'value': np.int64(18),
#    'left': {'index': np.int64(1),
#     'value': np.int64(111873),
#     'left': {'index': np.int64(1),
#      'value': np.int64(86983),
#      'left': {'index': np.int64(3),
#       'value': np.int64(370),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(327),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(0),
#      'value': np.int64(63),
#      'left': {'index': np.int64(0),
#       'value': np.int64(51),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(410),
#       'left': np.int64(0),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(3),
#     'value': np.int64(724),
#     'left': {'index': np.int64(3),
#      'value': np.int64(575),
#      'left': {'index': np.int64(2),
#       'value': np.int64(20),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(38),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(20),
#      'left': {'index': np.int64(3),
#       'value': np.int64(832),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(36),
#       'left': np.int64(0),
#       'right': np.int64(1)}}}},
#   'right': {'index': np.int64(0),
#    'value': np.int64(27),
#    'left': {'index': np.int64(1),
#     'value': np.int64(112244),
#     'left': {'index': np.int64(2),
#      'value': np.int64(39),
#      'left': np.int64(0),
#      'right': np.int64(0)},
#     'right': {'index': np.int64(3),
#      'value': np.int64(680),
#      'left': {'index': np.int64(2),
#       'value': np.int64(39),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(680),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(1),
#     'value': np.int64(128475),
#     'left': {'index': np.int64(3),
#      'value': np.int64(621),
#      'left': {'index': np.int64(3),
#       'value': np.int64(318),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(31),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(148935),
#      'left': {'index': np.int64(0),
#       'value': np.int64(34),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(49),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(3),
#   'value': np.int64(789),
#   'left': {'index': np.int64(3),
#    'value': np.int64(713),
#    'left': {'index': np.int64(3),
#     'value': np.int64(699),
#     'left': {'index': np.int64(3),
#      'value': np.int64(574),
#      'left': {'index': np.int64(0),
#       'value': np.int64(66),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(38),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(102666),
#      'left': {'index': np.int64(2),
#       'value': np.int64(13),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(14),
#       'left': np.int64(1),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(37),
#     'left': {'index': np.int64(0),
#      'value': np.int64(69),
#      'left': {'index': np.int64(3),
#       'value': np.int64(714),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(757),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(39751),
#      'left': {'index': np.int64(1),
#       'value': np.int64(29121),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(38),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(0),
#    'value': np.int64(45),
#    'left': {'index': np.int64(0),
#     'value': np.int64(42),
#     'left': {'index': np.int64(0),
#      'value': np.int64(41),
#      'left': {'index': np.int64(1),
#       'value': np.int64(42884),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(37),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(9),
#      'left': {'index': np.int64(0),
#       'value': np.int64(43),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(807),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(3),
#     'value': np.int64(826),
#     'left': {'index': np.int64(0),
#      'value': np.int64(55),
#      'left': {'index': np.int64(3),
#       'value': np.int64(792),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(143416),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(839),
#      'left': {'index': np.int64(1),
#       'value': np.int64(143823),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(135584),
#       'left': np.int64(0),
#       'right': np.int64(1)}}}}},
#  {'index': np.int64(2),
#   'value': np.int64(18),
#   'left': {'index': np.int64(1),
#    'value': np.int64(23956),
#    'left': {'index': np.int64(0),
#     'value': np.int64(62),
#     'left': {'index': np.int64(3),
#      'value': np.int64(822),
#      'left': {'index': np.int64(1),
#       'value': np.int64(23453),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(16),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(761),
#      'left': {'index': np.int64(2),
#       'value': np.int64(11),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(14),
#       'left': np.int64(0),
#       'right': np.int64(0)}}},
#    'right': {'index': np.int64(0),
#     'value': np.int64(19),
#     'left': {'index': np.int64(3),
#      'value': np.int64(508),
#      'left': {'index': np.int64(3),
#       'value': np.int64(396),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(104925),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(3),
#      'value': np.int64(632),
#      'left': {'index': np.int64(0),
#       'value': np.int64(31),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(638),
#       'left': np.int64(0),
#       'right': np.int64(0)}}}},
#   'right': {'index': np.int64(0),
#    'value': np.int64(67),
#    'left': {'index': np.int64(1),
#     'value': np.int64(45279),
#     'left': {'index': np.int64(3),
#      'value': np.int64(378),
#      'left': {'index': np.int64(0),
#       'value': np.int64(30),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(807),
#       'left': np.int64(0),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(24),
#      'left': {'index': np.int64(0),
#       'value': np.int64(19),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(60),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(24),
#     'left': {'index': np.int64(0),
#      'value': np.int64(68),
#      'left': {'index': np.int64(1),
#       'value': np.int64(33269),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(779),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(2),
#      'value': np.int64(36),
#      'left': {'index': np.int64(3),
#       'value': np.int64(585),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(398),
#       'left': np.int64(1),
#       'right': np.int64(0)}}}}},
#  {'index': np.int64(1),
#   'value': np.int64(141544),
#   'left': {'index': np.int64(3),
#    'value': np.int64(816),
#    'left': {'index': np.int64(0),
#     'value': np.int64(19),
#     'left': {'index': np.int64(2),
#      'value': np.int64(12),
#      'left': {'index': np.int64(2),
#       'value': np.int64(9),
#       'left': np.int64(0),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(2),
#       'value': np.int64(36),
#       'left': np.int64(1),
#       'right': np.int64(0)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(48307),
#      'left': {'index': np.int64(1),
#       'value': np.int64(29269),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(135329),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(33),
#     'left': {'index': np.int64(2),
#      'value': np.int64(6),
#      'left': {'index': np.int64(3),
#       'value': np.int64(849),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(1),
#       'value': np.int64(108422),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(49063),
#      'left': {'index': np.int64(1),
#       'value': np.int64(26078),
#       'left': np.int64(1),
#       'right': np.int64(0)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(818),
#       'left': np.int64(0),
#       'right': np.int64(1)}}}},
#   'right': {'index': np.int64(3),
#    'value': np.int64(826),
#    'left': {'index': np.int64(2),
#     'value': np.int64(15),
#     'left': {'index': np.int64(0),
#      'value': np.int64(40),
#      'left': {'index': np.int64(1),
#       'value': np.int64(142019),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(68),
#       'left': np.int64(0),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(0),
#      'value': np.int64(36),
#      'left': {'index': np.int64(2),
#       'value': np.int64(32),
#       'left': np.int64(0),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(0),
#       'value': np.int64(39),
#       'left': np.int64(1),
#       'right': np.int64(1)}}},
#    'right': {'index': np.int64(2),
#     'value': np.int64(28),
#     'left': {'index': np.int64(2),
#      'value': np.int64(18),
#      'left': {'index': np.int64(2),
#       'value': np.int64(9),
#       'left': np.int64(1),
#       'right': np.int64(1)},
#      'right': {'index': np.int64(3),
#       'value': np.int64(826),
#       'left': np.int64(1),
#       'right': np.int64(1)}},
#     'right': {'index': np.int64(1),
#      'value': np.int64(141635),
#      'left': np.int64(0),
#      'right': np.int64(0)}}}}]

# %%
random_forest_predict(model, input_set.values[0])
# Out:
# np.int64(1)

# %%
preds = [random_forest_predict(model, row) for row in input_set.values]

# %%
preds = [random_forest_predict(model, row) for row in input_set.values]

# %%
idx = np.random.permutation(len(df))
split = int(0.8 * len(df))

train_idx, test_idx = idx[:split], idx[split:]

X_train, X_test = input_set.values[train_idx], input_set.values[test_idx]
y_train, y_test = output_set.values[train_idx], output_set.values[test_idx]

# %%
model = random_forest_train(X_train, y_train)
preds = [random_forest_predict(model, row) for row in X_test]

accuracy = sum(preds[i] == y_test[i] for i in range(len(y_test))) / len(y_test)
accuracy
# Out:
# np.float64(0.484)

# %%
import pickle

with open("rf_model.pkl", "wb") as f:
    pickle.dump(model, f)

with open("features.pkl", "wb") as f:
    pickle.dump(list(input_set.columns), f)
